# %% [markdown]
# # Deep Learning Baselines
#
# This notebook trains and evaluates standard deep learning baselines using PyTorch Frame: TabTransformer, FT-Transformer, and MLP (ResNet) on the PRAGMA tasks.

# %%
# !pip install pytorch-frame scikit-learn

# %%
import sys
sys.path.append('../src')

from models.train_dl_baselines import train_dl_model, main as run_dl_baselines

# Run all deep learning baselines
run_dl_baselines()
