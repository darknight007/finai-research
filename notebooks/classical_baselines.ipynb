# %% [markdown]
# # Classical ML Baselines
#
# This notebook trains and evaluates standard non-deep learning baselines: XGBoost, LightGBM, CatBoost, Random Forest, and Logistic Regression on the PRAGMA tasks.

# %%
# !pip install xgboost lightgbm catboost scikit-learn

# %%
import sys
sys.path.append('../src')

from models.train_classical_baselines import train_and_evaluate, main as run_baselines

# Run all baselines
run_baselines()
